# %% [markdown]
# # モデル学習

# %% [markdown]
# ## Library Import

# %%
# データの取り扱いに関するライブラリ
import numpy as np # 高速計算
import pandas as pd # 表データの扱い

# 可視化に関するライブラリ
import matplotlib.pyplot as plt
import japanize_matplotlib

from sklearn.model_selection import GroupKFold
import lightgbm as lgb

import gc
import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %%
# 自身がファイルを格納したディレクトリを指定
ROOT_DIR = '../../input/'
data_definition_path = ROOT_DIR + 'data_definition.xlsx'
intermediate_path = '../../output/intermediate_file/'
model_path = '../../output/model/'
oof_path = '../../output/oof/'
fi_path = '../../output/fi/'

# スクリプトのバージョン指定
fe_ver = 1
training_ver = 1

today = dt.datetime.today().strftime("%Y%m%d")

# %% [markdown]
# ## File Import

# %%
train_df = pd.read_csv(f'{intermediate_path}train_df_fe_v{fe_ver}.csv')

# %%
date_col = 'target_ym'
target_col = 'money_room'

# %% [markdown]
# ## 使用特徴量の選択

# %%
fe_cols = train_df.columns.to_list()
fe_cols.remove(target_col)
fe_cols.remove('unit_area_max')

# %% [markdown]
# #### カテゴリ型へ変更

# %%
reform_cols = [
    'reform_interior 1',
    'reform_interior 2',
    'reform_interior 3',
    'reform_interior 4',
    'reform_interior 5',
    'reform_interior 6',
    'reform_exterior 1',
    'reform_exterior 1 ',
    'reform_exterior 2',
    'reform_wet_area 1',
    'reform_wet_area 2',
    'reform_wet_area 3',
    'reform_wet_area 4',
    'reform_wet_area 5',
    'reform_wet_area 6'
]

# %%
tag_groups = {
    # 土地まわりのタグ
    'land_price': [
        c for c in train_df.columns
        if c.startswith('土地価格_')
    ],

    # 建物性能・構造
    'building_struct': [
        c for c in train_df.columns
        if c.startswith('建物構造・性能_')
    ],

    # 建物の給排水・インフラ設備
    'infra': [
        c for c in train_df.columns
        if c.startswith('建物設備（給排水・インフラ）_')
    ],

    # 立地プレミアム（タグ由来のもの）
    'location_premium': [
        c for c in train_df.columns
        if c.startswith('立地プレミアム_')
    ],

    # 環境プレミアム（タグ由来のもの）
    'environment': [
        c for c in train_df.columns
        if c.startswith('環境プレミアム_')
    ],

    # 専有部分設備
    'senyu': [
        c for c in train_df.columns
        if c.startswith('専有部分設備')
    ],

    # 用途・投資セグメント
    'sales_status': [
        c for c in train_df.columns
        if c.startswith('用途・投資セグメント_売買ステータス_')
    ],
    'certificate': [
        c for c in train_df.columns
        if c.startswith('用途・投資セグメント_不動産の証明書・性能評価_')
    ],
}

tag_cols = []

for _, cols in tag_groups.items():
    tag_cols += cols

# %%
cat_cols = ['building_category', 'Prefecture name', 'City/town/village name', 
            'land_toshi', 'land_area_kind', 'land_youto', 'building_land_chimoku',
            'land_road_cond', 'building_area_kind', 'access_zone'
] + reform_cols + tag_cols

train_df[cat_cols] = train_df[cat_cols].astype('category')

# %%
# すべての category 列のリスト
obj_cols = train_df.select_dtypes(['object']).columns.tolist()

train_df[obj_cols] = train_df[obj_cols].astype('category')

# %% [markdown]
# ## モデルの学習

# %%
base_cols = fe_cols.copy()
low_cols = fe_cols.copy()

y_all = train_df[target_col].astype(float)
y_all_log = np.log(y_all)

# %%
LOW_PRICE_TH = 10_000_000  # 低価格の閾値（1,000万円）

# LightGBM のベースパラメータ（あなたの設定）
base_params = {
    "n_estimators": 1000,
    "learning_rate": 0.05,
    "num_leaves": 100,
    "max_depth": -1,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "random_state": 42,
    "n_jobs": -1
}

low_params = {
    "num_leaves": 64,
    "min_child_samples": 30,
}

fi_list_base = []
fi_list_low = []

# %%
def mape(y_true, y_pred):
    """MAPE計算（%ではなくratio）。"""
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return np.mean(np.abs(y_true - y_pred) / np.clip(y_true, 1e-6, None))


def predict_with_base_and_low(base_model, low_model,
                              X_base, X_low,
                              low_th_log=np.log(LOW_PRICE_TH)):
    """
    base_model / low_model の両方で予測し、
    base_model の予測が低価格帯のものは low_model の予測に差し替える。
    （logスケールで返す）
    """
    base_pred_log = base_model.predict(X_base)
    low_pred_log = low_model.predict(X_low)

    pred_log = base_pred_log.copy()
    low_mask = base_pred_log <= low_th_log
    pred_log[low_mask] = low_pred_log[low_mask]

    return pred_log

# %%
def parse_year(date_input):
    try:
        s = str(date_input)
        if len(s) < 4:
            return np.nan
        return int(s[:4])
    except:
        return np.nan
    
train_df['target_year'] = train_df['target_ym'].apply(parse_year)

# %%
year_col = "target_year"
mask_train_cv = train_df[year_col] <= 2021   # 2019–2021 → CV
mask_holdout = train_df[year_col] == 2022    # 2022 → 完全 hold-out

idx_cv = train_df.index[mask_train_cv]
idx_ho = train_df.index[mask_holdout]

X_cv_base = train_df.loc[idx_cv, base_cols]
X_cv_low  = train_df.loc[idx_cv, low_cols]
y_cv_log  = y_all_log.loc[idx_cv]
groups_cv = train_df.loc[idx_cv, "building_id"]

X_ho_base = train_df.loc[idx_ho, base_cols]
X_ho_low  = train_df.loc[idx_ho, low_cols]
y_ho      = y_all.loc[idx_ho]      # MAPEは元スケールで見る

print(f"CV 用データ: {len(X_cv_base)} 行")
print(f"2022 hold-out データ: {len(X_ho_base)} 行")
# Out:
# CV 用データ: 274358 行
# 2022 hold-out データ: 89566 行

# %%
# OOF 用配列（log）
oof_pred_log = np.full(len(train_df), np.nan, dtype=float)
# 2022 HO は fold ごとの予測を平均
ho_pred_log_accum = np.zeros(len(idx_ho), dtype=float)

gkf = GroupKFold(n_splits=5)

print("=== GroupKFold CV (2019–2021, group=building_id) ===")
for fold, (tr_idx_local, va_idx_local) in enumerate(gkf.split(X_cv_base, y_cv_log, groups_cv), 1):
    tr_idx = idx_cv[tr_idx_local]
    va_idx = idx_cv[va_idx_local]

    # -------------------------
    # base_model の学習
    # -------------------------
    X_tr_base = train_df.loc[tr_idx, base_cols]
    y_tr_log  = y_all_log.loc[tr_idx]

    base_model = lgb.LGBMRegressor(**base_params)
    base_model.fit(X_tr_base, y_tr_log)

    # -------------------------
    # low_model の学習（低価格帯だけ）
    # -------------------------
    mask_tr_low = (y_all.loc[tr_idx] <= LOW_PRICE_TH)
    tr_idx_low = tr_idx[mask_tr_low]

    X_tr_low = train_df.loc[tr_idx_low, low_cols]
    y_tr_low_log = y_all_log.loc[tr_idx_low]

    low_model = lgb.LGBMRegressor(**low_params)
    low_model.fit(X_tr_low, y_tr_low_log)

    # -------------------------
    # OOF 予測（2019–2021 の validation 部）
    # -------------------------
    X_va_base = train_df.loc[va_idx, base_cols]
    X_va_low  = train_df.loc[va_idx, low_cols]

    va_pred_log = predict_with_base_and_low(
        base_model, low_model,
        X_va_base, X_va_low
    )
    oof_pred_log[va_idx] = va_pred_log

    # -------------------------
    # 2022 hold-out 予測（foldごとに平均）
    # -------------------------
    ho_pred_log = predict_with_base_and_low(
        base_model, low_model,
        X_ho_base, X_ho_low
    )
    ho_pred_log_accum += ho_pred_log / gkf.n_splits

    # 参考：foldごとのスコア
    y_va = y_all.loc[va_idx]
    va_pred = np.exp(va_pred_log)
    fold_mape = mape(y_va, va_pred)
    print(f"Fold {fold}: val MAPE={fold_mape:.4f}")

        # ====== FI accumulate ======
    # base_model feature importance
    fi_base = pd.DataFrame({
        "feature": base_cols,
        "importance": base_model.booster_.feature_importance(importance_type="gain")
    })
    fi_base["fold"] = fold
    fi_list_base.append(fi_base)

    # low_model feature importance
    fi_low = pd.DataFrame({
        "feature": low_cols,
        "importance": low_model.booster_.feature_importance(importance_type="gain")
    })
    fi_low["fold"] = fold
    fi_list_low.append(fi_low)
# Out:
# === GroupKFold CV (2019–2021, group=building_id) ===
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.068110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67375
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 319
# [LightGBM] [Info] Start training from score 16.854185
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012392 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29445
# [LightGBM] [Info] Number of data points in the train set: 30564, number of used features: 281
# [LightGBM] [Info] Start training from score 15.844859
# Fold 1: val MAPE=0.1665
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.061261 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67522
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 320
# [LightGBM] [Info] Start training from score 16.850960
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011744 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29469
# [LightGBM] [Info] Number of data points in the train set: 30617, number of used features: 279
# [LightGBM] [Info] Start training from score 15.847730
# Fold 2: val MAPE=0.1653
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063358 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67684
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 319
# [LightGBM] [Info] Start training from score 16.853287
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011301 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29504
# [LightGBM] [Info] Number of data points in the train set: 30597, number of used features: 280
# [LightGBM] [Info] Start training from score 15.844109
# Fold 3: val MAPE=0.1649
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.069641 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67668
# [LightGBM] [Info] Number of data points in the train set: 219487, number of used features: 320
# [LightGBM] [Info] Start training from score 16.852061
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011738 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29624
# [LightGBM] [Info] Number of data points in the train set: 30830, number of used features: 281
# [LightGBM] [Info] Start training from score 15.845252
# Fold 4: val MAPE=0.1641
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.062769 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67545
# [LightGBM] [Info] Number of data points in the train set: 219487, number of used features: 318
# [LightGBM] [Info] Start training from score 16.852197
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011713 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 29476
# [LightGBM] [Info] Number of data points in the train set: 30580, number of used features: 281
# [LightGBM] [Info] Start training from score 15.845351
# Fold 5: val MAPE=0.1647

# %%
# OOF / HO スコア
oof_mask_valid = ~np.isnan(oof_pred_log)
y_oof = y_all.loc[oof_mask_valid]
oof_pred = np.exp(oof_pred_log[oof_mask_valid])
oof_mape = mape(y_oof, oof_pred)

ho_pred = np.exp(ho_pred_log_accum)
ho_mape = mape(y_ho, ho_pred)

print(f"OOF MAPE (2019–2021) : {oof_mape:.6f}")
print(f"2022 hold-out MAPE  : {ho_mape:.6f}")
# Out:
# OOF MAPE (2019–2021) : 0.165104
# 2022 hold-out MAPE  : 0.150159

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_ho, ho_pred, alpha=0.3)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Train)")

# 45度線（完璧な予測ライン）
min_val = min(y_ho.min(), ho_pred.min())
max_val = max(y_ho.max(), ho_pred.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')

plt.show()

# %% [markdown]
# ## 特徴量重要度

# %%
base_fi = (
    pd.concat(fi_list_base)
      .groupby("feature")["importance"]
      .mean()
      .reset_index()
      .sort_values("importance", ascending=False)
)

low_fi = (
    pd.concat(fi_list_low)
      .groupby("feature")["importance"]
      .mean()
      .reset_index()
      .sort_values("importance", ascending=False)
)

# %%
base_fi.to_csv(f'{fi_path}feature_importance_base.csv', index=False)
low_fi.to_csv(f'{fi_path}feature_importance_low.csv', index=False)

# %% [markdown]
# #### 特徴量重要度==0を削除

# %%
excluded_fe_base = base_fi.query("importance == 0")["feature"].tolist()
excluded_fe_low  = low_fi.query("importance == 0")["feature"].tolist()

print(f"[Base] Removed {len(excluded_fe_base)} features")
print(f"[Low]  Removed {len(excluded_fe_low)} features")

base_cols_filtered = [c for c in fe_cols if c not in excluded_fe_base]
low_cols_filtered = [c for c in fe_cols if c not in excluded_fe_low]
# Out:
# [Base] Removed 59 features
# [Low]  Removed 126 features

# %% [markdown]
# #### OOFのMAPEを評価

# %%
# OOF / HO 用配列（log）
oof_pred_log_filtered = np.full(len(train_df), np.nan)
ho_pred_log_accum_filtered = np.zeros(len(idx_ho), dtype=float)

X_ho_base_filtered = train_df.loc[idx_ho, base_cols_filtered]
X_ho_low_filtered  = train_df.loc[idx_ho, low_cols_filtered]

gkf = GroupKFold(n_splits=5)

for fold, (tr_idx_local, va_idx_local) in enumerate(gkf.split(X_cv_base, y_cv_log, groups_cv), 1):
    tr_idx = idx_cv[tr_idx_local]
    va_idx = idx_cv[va_idx_local]

    # ==== 低価格帯インデックス（毎 fold 作り直し）====
    mask_tr_low = (y_all.loc[tr_idx] <= LOW_PRICE_TH)
    tr_idx_low = tr_idx[mask_tr_low]

    # ==== 新しい特徴量セット ====
    X_tr_base = train_df.loc[tr_idx, base_cols_filtered]
    X_tr_low  = train_df.loc[tr_idx_low, low_cols_filtered]
    X_va_base = train_df.loc[va_idx, base_cols_filtered]
    X_va_low  = train_df.loc[va_idx, low_cols_filtered]

    # ==== base model ====
    base_model_f = lgb.LGBMRegressor(**base_params)
    base_model_f.fit(X_tr_base, y_all_log[tr_idx])

    # ==== low model ====
    low_model_f = lgb.LGBMRegressor(**low_params)
    low_model_f.fit(X_tr_low, y_all_log[tr_idx_low])

    # ==== OOF prediction ====
    va_pred_log = predict_with_base_and_low(
        base_model_f, low_model_f,
        X_va_base, X_va_low
    )
    oof_pred_log_filtered[va_idx] = va_pred_log

    # ==== 2022 HO prediction（fold ごとに平均）====
    ho_pred_log = predict_with_base_and_low(
        base_model_f, low_model_f,
        X_ho_base_filtered, X_ho_low_filtered
    )
    ho_pred_log_accum_filtered += ho_pred_log / gkf.n_splits

# ===== OOF MAPE (filtered) =====
oof_pred_filtered = np.exp(oof_pred_log_filtered[oof_mask_valid])
oof_mape_filtered = mape(y_oof, oof_pred_filtered)
print(f"OOF MAPE (after removing FI=0) : {oof_mape_filtered:.6f}")

# ===== HO MAPE (filtered) =====
ho_pred_filtered = np.exp(ho_pred_log_accum_filtered)
ho_mape_filtered = mape(y_ho, ho_pred_filtered)
print(f"HO  MAPE (after removing FI=0) : {ho_mape_filtered:.6f}")
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.057765 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67249
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 283
# [LightGBM] [Info] Start training from score 16.854185
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008816 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26625
# [LightGBM] [Info] Number of data points in the train set: 30564, number of used features: 216
# [LightGBM] [Info] Start training from score 15.844859
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.060645 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67395
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 283
# [LightGBM] [Info] Start training from score 16.850960
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26668
# [LightGBM] [Info] Number of data points in the train set: 30617, number of used features: 215
# [LightGBM] [Info] Start training from score 15.847730
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.062699 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67559
# [LightGBM] [Info] Number of data points in the train set: 219486, number of used features: 283
# [LightGBM] [Info] Start training from score 16.853287
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008513 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26691
# [LightGBM] [Info] Number of data points in the train set: 30597, number of used features: 216
# [LightGBM] [Info] Start training from score 15.844109
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.054247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67535
# [LightGBM] [Info] Number of data points in the train set: 219487, number of used features: 283
# [LightGBM] [Info] Start training from score 16.852061
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008772 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26727
# [LightGBM] [Info] Number of data points in the train set: 30830, number of used features: 215
# [LightGBM] [Info] Start training from score 15.845252
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 67418
# [LightGBM] [Info] Number of data points in the train set: 219487, number of used features: 283
# [LightGBM] [Info] Start training from score 16.852197
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008880 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 26662
# [LightGBM] [Info] Number of data points in the train set: 30580, number of used features: 215
# [LightGBM] [Info] Start training from score 15.845351
# OOF MAPE (after removing FI=0) : 0.165307
# HO  MAPE (after removing FI=0) : 0.150362

# %%
train_result_df = train_df[fe_cols + [target_col, 'unit_area_max']].copy()

# 初期化（全行 NaN）
train_result_df['oof_pred', 'ho_pred'] = np.nan

# 2022 年だけマスクを作る
mask_ho = (train_result_df['target_ym'].astype(str).str.startswith("2022"))

# OOF が存在する valid index に埋め込む
train_result_df.loc[oof_mask_valid, 'oof_pred'] = oof_pred_filtered
train_result_df.loc[mask_ho, 'ho_pred'] = ho_pred_filtered

print(train_result_df[['oof_pred', "ho_pred"]].head())
print(train_result_df[['oof_pred', "ho_pred"]].isna().mean())

train_result_df.to_csv(f'{oof_path}oof.csv', index=False)
# Out:
#        oof_pred  ho_pred
# 0  1.225757e+07      NaN
# 1  2.114793e+07      NaN
# 2  2.362252e+07      NaN
# 3  2.072595e+07      NaN
# 4  1.851755e+07      NaN
# oof_pred    0.246112
# ho_pred     0.753888
# dtype: float64

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_oof, oof_pred_filtered, alpha=0.3)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted (Train)")

# 45度線（完璧な予測ライン）
min_val = min(y_oof.min(), oof_pred_filtered.min())
max_val = max(y_oof.max(), oof_pred_filtered.max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')

plt.show()

# %% [markdown]
# ## 最終モデル

# %%
# 特徴量重要度スコア0の特徴量を除外したモデルのOOFの方がMAPEよければ書き換え
base_cols = base_cols_filtered.copy()
low_cols = low_cols_filtered.copy()

idx_full = train_df.index

# %%
from sklearn.model_selection import KFold

def train_kfold_models(df, y_log, cols, params, n_splits=5):
    models = []
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    for train_idx, valid_idx in kf.split(df):
        X_tr = df.iloc[train_idx][cols]
        y_tr = y_log.iloc[train_idx]

        model = lgb.LGBMRegressor(**params)
        model.fit(X_tr, y_tr)
        models.append(model)

    return models


# -------------------------
# base model の 5fold
# -------------------------
X_full_base = train_df.loc[idx_full, base_cols]
y_full_log  = y_all_log.loc[idx_full]

base_models = train_kfold_models(
    X_full_base, y_full_log, base_cols, base_params
)

# -------------------------
# low model の 5fold
# -------------------------
mask_full_low = (y_all.loc[idx_full] <= LOW_PRICE_TH)
idx_full_low = idx_full[mask_full_low]

X_full_low_sub = train_df.loc[idx_full_low, low_cols]
y_full_low_log = y_all_log.loc[idx_full_low]

low_models = train_kfold_models(
    X_full_low_sub, y_full_low_log, low_cols, low_params
)
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.079642 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 62927
# [LightGBM] [Info] Number of data points in the train set: 291139, number of used features: 283
# [LightGBM] [Info] Start training from score 16.872611
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.071603 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 63170
# [LightGBM] [Info] Number of data points in the train set: 291139, number of used features: 283
# [LightGBM] [Info] Start training from score 16.872433
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.077874 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 62865
# [LightGBM] [Info] Number of data points in the train set: 291139, number of used features: 283
# [LightGBM] [Info] Start training from score 16.873890
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.083940 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 63047
# [LightGBM] [Info] Number of data points in the train set: 291139, number of used features: 283
# [LightGBM] [Info] Start training from score 16.872477
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 63420
# [LightGBM] [Info] Number of data points in the train set: 291140, number of used features: 283
# [LightGBM] [Info] Start training from score 16.872839
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010725 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28250
# [LightGBM] [Info] Number of data points in the train set: 39445, number of used features: 216
# [LightGBM] [Info] Start training from score 15.843841
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009796 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28217
# [LightGBM] [Info] Number of data points in the train set: 39445, number of used features: 216
# [LightGBM] [Info] Start training from score 15.843557
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010762 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28284
# [LightGBM] [Info] Number of data points in the train set: 39446, number of used features: 216
# [LightGBM] [Info] Start training from score 15.843837
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010497 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28213
# [LightGBM] [Info] Number of data points in the train set: 39446, number of used features: 216
# [LightGBM] [Info] Start training from score 15.843633
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 28218
# [LightGBM] [Info] Number of data points in the train set: 39446, number of used features: 216
# [LightGBM] [Info] Start training from score 15.844970

# %% [markdown]
# ## モデルの出力

# %%
import pickle
base_dict = {
    "base_models": base_models,
    "base_cols": base_cols
}
low_dict = {
    "low_models": low_models,
    "low_cols": low_cols
}

with open(f'{model_path}base_models_v{training_ver}.pkl', "wb") as f:
    pickle.dump(base_dict, f)

with open(f'{model_path}low_models_v{training_ver}.pkl', "wb") as f:
    pickle.dump(low_dict, f)

# %%
cat_cols
# Out:
# ['building_category',
#  'Prefecture name',
#  'City/town/village name',
#  'land_toshi',
#  'land_area_kind',
#  'land_youto',
#  'building_land_chimoku',
#  'land_road_cond',
#  'building_area_kind',
#  'access_zone',
#  'reform_interior 1',
#  'reform_interior 2',
#  'reform_interior 3',
#  'reform_interior 4',
#  'reform_interior 5',
#  'reform_interior 6',
#  'reform_exterior 1',
#  'reform_exterior 1 ',
#  'reform_exterior 2',
#  'reform_wet_area 1',
#  'reform_wet_area 2',
#  'reform_wet_area 3',
#  'reform_wet_area 4',
#  'reform_wet_area 5',
#  'reform_wet_area 6',
#  '土地価格_低層住宅地',
#  '土地価格_南道路',
#  '土地価格_敷地延長・変形地',
#  '土地価格_角地',
#  '建物構造・性能_1階の物件',
#  '建物構造・性能_24時間有人管理',
#  '建物構造・性能_2階以上',
#  '建物構造・性能_TVモニタ付インターホン',
#  '建物構造・性能_ごみ出し24時間OK',
#  '建物構造・性能_エレベーター',
#  '建物構造・性能_オートロック',
#  '建物構造・性能_キッズルーム',
#  '建物構造・性能_コンシェルジュサービス',
#  '建物構造・性能_シングル&DINKS向け',
#  '建物構造・性能_セキュリティー充実',
#  '建物構造・性能_セキュリティ会社加入済み',
#  '建物構造・性能_タイル貼り',
#  '建物構造・性能_タワーマンション',
#  '建物構造・性能_テラス',
#  '建物構造・性能_デザイナーズ',
#  '建物構造・性能_ハイグレードマンション',
#  '建物構造・性能_バイク置き場あり',
#  '建物構造・性能_バリアフリー',
#  '建物構造・性能_バルコニー',
#  '建物構造・性能_フリーアクセス',
#  '建物構造・性能_フロントサービス',
#  '建物構造・性能_フローリング',
#  '建物構造・性能_ペット用施設',
#  '建物構造・性能_メゾネット',
#  '建物構造・性能_リゾートマンション',
#  '建物構造・性能_ルーフバルコニー',
#  '建物構造・性能_ロフト付き',
#  '建物構造・性能_二世帯住宅向き',
#  '建物構造・性能_低層マンション',
#  '建物構造・性能_保証付住宅',
#  '建物構造・性能_免震構造',
#  '建物構造・性能_内廊下',
#  '建物構造・性能_出窓',
#  '建物構造・性能_分譲物件',
#  '建物構造・性能_分譲賃貸',
#  '建物構造・性能_制震構造',
#  '建物構造・性能_南向き',
#  '建物構造・性能_吹き抜け',
#  '建物構造・性能_和室',
#  '建物構造・性能_外断熱',
#  '建物構造・性能_大規模マンション',
#  '建物構造・性能_宅配ボックス',
#  '建物構造・性能_室内洗濯機置場',
#  '建物構造・性能_家具・家電付',
#  '建物構造・性能_専用庭',
#  '建物構造・性能_屋上・ルーフバルコニー',
#  '建物構造・性能_最上階',
#  '建物構造・性能_洗濯機置場あり',
#  '建物構造・性能_照明器具付',
#  '建物構造・性能_管理人常駐',
#  '建物構造・性能_耐震・制震・免震構造',
#  '建物構造・性能_耐震構造',
#  '建物構造・性能_複層ガラス採用（二重サッシ・防犯サッシ等）',
#  '建物構造・性能_角部屋',
#  '建物構造・性能_防犯カメラ',
#  '建物構造・性能_駐車場あり',
#  '建物構造・性能_駐輪場あり',
#  '建物設備（給排水・インフラ）_オール電化',
#  '建物設備（給排水・インフラ）_ガスその他',
#  '建物設備（給排水・インフラ）_プロパンガス',
#  '建物設備（給排水・インフラ）_下水',
#  '建物設備（給排水・インフラ）_井戸',
#  '建物設備（給排水・インフラ）_公営水道',
#  '建物設備（給排水・インフラ）_太陽光発電システム',
#  '建物設備（給排水・インフラ）_排水その他',
#  '建物設備（給排水・インフラ）_水道その他',
#  '建物設備（給排水・インフラ）_汲取',
#  '建物設備（給排水・インフラ）_浄化槽',
#  '建物設備（給排水・インフラ）_環境にやさしい',
#  '建物設備（給排水・インフラ）_都市ガス',
#  '立地プレミアム_最寄り駅が始発駅',
#  '立地プレミアム_複数路線',
#  '環境プレミアム_コンビニ 400ｍ以内',
#  '環境プレミアム_コンビニ 800ｍ以内',
#  '環境プレミアム_スーパー 800ｍ以内',
#  '環境プレミアム_フィットネス施設（プール含む）800m以内',
#  '環境プレミアム_中学校 800m以内',
#  '環境プレミアム_保育園・幼稚園 400m以内',
#  '環境プレミアム_公園 400ｍ以内',
#  '環境プレミアム_子育てに嬉しい環境',
#  '環境プレミアム_小学校 800ｍ以内',
#  '環境プレミアム_総合病院 800ｍ以内',
#  '専有部分設備_キッチン_IHコンロ',
#  '専有部分設備_キッチン_カウンターキッチン',
#  '専有部分設備_キッチン_ガスコンロ',
#  '専有部分設備_キッチン_ガスコンロ設置済',
#  '専有部分設備_キッチン_コンロ一口',
#  '専有部分設備_キッチン_コンロ三口',
#  '専有部分設備_キッチン_コンロ二口',
#  '専有部分設備_キッチン_コンロ四口以上',
#  '専有部分設備_キッチン_システムキッチン',
#  '専有部分設備_キッチン_ディスポーザー',
#  '専有部分設備_キッチン_冷蔵庫あり',
#  '専有部分設備_キッチン_浄水器・活水器',
#  '専有部分設備_キッチン_給湯',
#  '専有部分設備_キッチン_電気コンロ',
#  '専有部分設備_キッチン_食器洗い乾燥機',
#  '専有部分設備_トイレ_トイレなし',
#  '専有部分設備_トイレ_共同トイレ',
#  '専有部分設備_トイレ_専用トイレ',
#  '専有部分設備_トイレ_温水洗浄便座',
#  '専有部分設備_収納_ウォークインクローゼット',
#  '専有部分設備_収納_クローゼット',
#  '専有部分設備_収納_シューズインクローゼット',
#  '専有部分設備_収納_シューズクローク',
#  '専有部分設備_収納_シューズボックス',
#  '専有部分設備_収納_トランクルーム',
#  '専有部分設備_収納_パントリー',
#  '専有部分設備_収納_全居室収納',
#  '専有部分設備_収納_床下収納',
#  '専有部分設備_浴室・洗面_オートバス',
#  '専有部分設備_浴室・洗面_シャワー',
#  '専有部分設備_浴室・洗面_シャワー付洗面化粧台',
#  '専有部分設備_浴室・洗面_バスなし',
#  '専有部分設備_浴室・洗面_バス・トイレ別',
#  '専有部分設備_浴室・洗面_共同バス',
#  '専有部分設備_浴室・洗面_専用バス',
#  '専有部分設備_浴室・洗面_洗面所独立',
#  '専有部分設備_浴室・洗面_浴室1.6×1.8M以上',
#  '専有部分設備_浴室・洗面_浴室1.6×2.0M以上',
#  '専有部分設備_浴室・洗面_浴室TV',
#  '専有部分設備_浴室・洗面_浴室乾燥機',
#  '専有部分設備_浴室・洗面_浴室暖房',
#  '専有部分設備_浴室・洗面_追焚機能',
#  '専有部分設備_浴室・洗面_高温差湯式',
#  '専有部分設備_空調・暖房_エアコン',
#  '専有部分設備_空調・暖房_ガス暖房',
#  '専有部分設備_空調・暖房_冷房',
#  '専有部分設備_空調・暖房_床暖房',
#  '専有部分設備_空調・暖房_石油暖房',
#  '専有部分設備_通信_BSアンテナ',
#  '専有部分設備_通信_CATV',
#  '専有部分設備_通信_CATV利用料無料',
#  '専有部分設備_通信_CSアンテナ',
#  '専有部分設備_通信_インターネット使用料無料',
#  '専有部分設備_通信_インターネット対応',
#  '専有部分設備_通信_光ファイバー',
#  '専有部分設備_通信_有線放送',
#  '専有部分設備_通信_高速インターネット',
#  '用途・投資セグメント_売買ステータス_満室賃貸中',
#  '用途・投資セグメント_不動産の証明書・性能評価_インスペクション（建物検査）報告書',
#  '用途・投資セグメント_不動産の証明書・性能評価_住宅性能保証制度証明書',
#  '用途・投資セグメント_不動産の証明書・性能評価_修繕・点検の記録',
#  '用途・投資セグメント_不動産の証明書・性能評価_建築確認完了検査済証',
#  '用途・投資セグメント_不動産の証明書・性能評価_建設住宅性能評価書（新築時）',
#  '用途・投資セグメント_不動産の証明書・性能評価_建設住宅性能評価書（既存住宅）',
#  '用途・投資セグメント_不動産の証明書・性能評価_新築時・増改築時の設計図書',
#  '用途・投資セグメント_不動産の証明書・性能評価_瑕疵保証（不動産会社独自）付',
#  '用途・投資セグメント_不動産の証明書・性能評価_瑕疵保険（国交省指定）による保証付',
#  '用途・投資セグメント_不動産の証明書・性能評価_瑕疵保険（国交省指定）による保証利用可',
#  '用途・投資セグメント_不動産の証明書・性能評価_空き家バンク登録物件',
#  '用途・投資セグメント_不動産の証明書・性能評価_耐震基準適合証明書',
#  '用途・投資セグメント_不動産の証明書・性能評価_設計住宅性能評価書',
#  '用途・投資セグメント_不動産の証明書・性能評価_長期優良住宅認定通知書']
