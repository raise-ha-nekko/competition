# %%
import numpy as np
import pandas as pd
import pickle

# %%
test_df = pd.read_csv('./output/中間データ/test_with_時系列特徴量.csv')
test_df
# Out:
#       datetime   y week  soldout            name   kcal         remarks  \
# 0   2014-10-01 NaN    水        1           メンチカツ  420.0             NaN
# 1   2014-10-02 NaN    木        0       バーベキューチキン  415.0             NaN
# 2   2014-10-03 NaN    金        0      豚肉のマスタード焼き  405.0             NaN
# 3   2014-10-06 NaN    月        1            麻婆春雨  400.0             NaN
# 4   2014-10-07 NaN    火        0        厚揚げ肉みそ炒め  430.0             NaN
# 5   2014-10-08 NaN    水        0    完熟トマトのホットカレー  420.0             NaN
# 6   2014-10-09 NaN    木        0          豚キムチ炒め  435.0             NaN
# 7   2014-10-10 NaN    金        0          ポークカレー    NaN        お楽しみメニュー
# 8   2014-10-14 NaN    火        0         若鶏梅肉包揚げ  408.0             NaN
# 9   2014-10-15 NaN    水        1         ミックスグリル  450.0    料理長のこだわりメニュー
# 10  2014-10-16 NaN    木        0      豚肉と白菜の中華炒め  400.0             NaN
# 11  2014-10-17 NaN    金        0            ヒレカツ  415.0             NaN
# 12  2014-10-20 NaN    月        1             豚柳川  426.0             NaN
# 13  2014-10-21 NaN    火        0         ポーク生姜焼き  410.0             NaN
# 14  2014-10-22 NaN    水        1            麻婆豆腐  415.0             NaN
# 15  2014-10-23 NaN    木        1       ビーフストロガノフ  428.0             NaN
# 16  2014-10-24 NaN    金        0            唐揚げ丼    NaN        お楽しみメニュー
# 17  2014-10-27 NaN    月        1           マス塩焼き  407.0             NaN
# 18  2014-10-28 NaN    火        1        チンジャオロース  425.0             NaN
# 19  2014-10-29 NaN    水        0         厚切イカフライ  430.0             NaN
# 20  2014-10-30 NaN    木        0     鶏肉と野菜の黒胡椒炒め  426.0             NaN
# 21  2014-10-31 NaN    金        0             八宝菜  436.0             NaN
# 22  2014-11-04 NaN    火        0         豚肉の生姜焼き  440.0             NaN
# 23  2014-11-05 NaN    水        1           ハンバーグ  425.0             NaN
# 24  2014-11-06 NaN    木        1    彩り野菜と鶏肉の黒酢あん  410.0             NaN
# 25  2014-11-07 NaN    金        0          ポークカレー    NaN        お楽しみメニュー
# 26  2014-11-10 NaN    月        0             親子煮  412.0             NaN
# 27  2014-11-11 NaN    火        0   ポークのバーベキューソテー  426.0             NaN
# 28  2014-11-12 NaN    水        0          鶏肉の唐揚げ  418.0             NaN
# 29  2014-11-13 NaN    木        1         白身魚味噌焼き  396.0  近隣に飲食店複合ビルオープン
# 30  2014-11-14 NaN    金        1      エビフライ・エビカツ  427.0             NaN
# 31  2014-11-17 NaN    月        1      野菜ごろごろシチュー  433.0             NaN
# 32  2014-11-18 NaN    火        1            麻婆豆腐  409.0             NaN
# 33  2014-11-19 NaN    水        0  ベルギー風チキンのクリーム煮  430.0    料理長のこだわりメニュー
# 34  2014-11-20 NaN    木        1          スタミナ炒め  421.0             NaN
# 35  2014-11-21 NaN    金        0           ロコモコ丼    NaN        お楽しみメニュー
# 36  2014-11-25 NaN    火        1     なすと挽肉のはさみ揚げ  460.0             NaN
# 37  2014-11-26 NaN    水        1         鶏肉の治部煮風  415.0             NaN
# 38  2014-11-27 NaN    木        0             牛丼風  420.0             NaN
# 39  2014-11-28 NaN    金        0    鶏肉のスイートチリソース  416.0             NaN
#
#             event  payday weather  ... y_5lag  y_rolling_mean_3  \
# 0             NaN     NaN       雨  ...   59.0              47.0
# 1             NaN     NaN       曇  ...   50.0               NaN
# 2             NaN     NaN      晴れ  ...   45.0               NaN
# 3             NaN     NaN       雨  ...   56.0               NaN
# 4             NaN     NaN      晴れ  ...   40.0               NaN
# 5             NaN     NaN      晴れ  ...    NaN               NaN
# 6   キャリアアップ支援セミナー     NaN       曇  ...    NaN               NaN
# 7             NaN     1.0      薄曇  ...    NaN               NaN
# 8             NaN     NaN      快晴  ...    NaN               NaN
# 9             NaN     NaN       雨  ...    NaN               NaN
# 10            NaN     NaN      晴れ  ...    NaN               NaN
# 11           ママの会     NaN      快晴  ...    NaN               NaN
# 12            NaN     NaN      薄曇  ...    NaN               NaN
# 13            NaN     NaN       雨  ...    NaN               NaN
# 14            NaN     NaN       雨  ...    NaN               NaN
# 15            NaN     NaN       雨  ...    NaN               NaN
# 16            NaN     NaN      快晴  ...    NaN               NaN
# 17            NaN     NaN      薄曇  ...    NaN               NaN
# 18            NaN     NaN      快晴  ...    NaN               NaN
# 19            NaN     NaN      快晴  ...    NaN               NaN
# 20            NaN     NaN      晴れ  ...    NaN               NaN
# 21            NaN     NaN       曇  ...    NaN               NaN
# 22            NaN     NaN      晴れ  ...    NaN               NaN
# 23            NaN     NaN       曇  ...    NaN               NaN
# 24            NaN     NaN       曇  ...    NaN               NaN
# 25            NaN     NaN      晴れ  ...    NaN               NaN
# 26            NaN     1.0      快晴  ...    NaN               NaN
# 27            NaN     NaN       曇  ...    NaN               NaN
# 28            NaN     NaN       曇  ...    NaN               NaN
# 29  キャリアアップ支援セミナー     NaN      快晴  ...    NaN               NaN
# 30            NaN     NaN      快晴  ...    NaN               NaN
# 31            NaN     NaN      薄曇  ...    NaN               NaN
# 32            NaN     NaN      快晴  ...    NaN               NaN
# 33            NaN     NaN      快晴  ...    NaN               NaN
# 34            NaN     NaN       曇  ...    NaN               NaN
# 35            NaN     NaN      快晴  ...    NaN               NaN
# 36            NaN     NaN       雨  ...    NaN               NaN
# 37            NaN     NaN       雨  ...    NaN               NaN
# 38            NaN     NaN      快晴  ...    NaN               NaN
# 39            NaN     NaN       曇  ...    NaN               NaN
#
#     y_rolling_max_3  y_rolling_min_3  y_rolling_mean_7  y_rolling_max_7  \
# 29              NaN                NaN               NaN               NaN
# 30              NaN                NaN               NaN               NaN
# 31              NaN                NaN               NaN               NaN
# 32              NaN                NaN               NaN               NaN
# 33              NaN                NaN               NaN               NaN
# 34              NaN                NaN               NaN               NaN
# 35              NaN                NaN               NaN               NaN
# 36              NaN                NaN               NaN               NaN
# 37              NaN                NaN               NaN               NaN
# 38              NaN                NaN               NaN               NaN
# 39              NaN                NaN               NaN               NaN
#
# [40 rows x 26 columns]

# %% [markdown]
# #### 日の抽出

# %%
test_df['day'] = test_df['datetime'].apply(lambda x : int(x.split('-')[2]))

# %% [markdown]
# #### 欠損値補完

# %%
test_df['payday'] = test_df['payday'].fillna(0)

# %%
test_df['precipitation'] = test_df['precipitation'].apply(lambda x: 0 if x == '--' else float(x) + 0.01)

# %%
test_df['kcal'] = test_df['kcal'].fillna(test_df.groupby('name')['kcal'].transform('mean'))
test_df['kcal_missing_flag'] = test_df['kcal'].isna().astype(int)
test_df['kcal'] = test_df['kcal'].fillna(-9999)

# %% [markdown]
# #### week

# %%
with open('./output/中間データ/target_encoding_week.pkl', 'rb') as f:
    week_map = pickle.load(f)

test_df['week'] = test_df['week'].map(week_map)

# %% [markdown]
# #### name

# %%
test_df['curry'] = test_df['name'].apply(lambda x : 1 if x.find("カレー") >=0 else 0)

# %%
# 読み込み
with open('./output/中間データ/menu_flags.pkl', 'rb') as f:
    menu_flags = pickle.load(f)

popular_menu = menu_flags['popular_menu']
unpopular_menu = menu_flags['unpopular_menu']

# フラグ列を再生成
test_df['popular'] = test_df['name'].apply(lambda x: 1 if x in popular_menu else 0)
test_df['unpopular'] = test_df['name'].apply(lambda x: 1 if x in unpopular_menu else 0)

# %% [markdown]
# #### weather

# %%
with open('./output/中間データ/target_encoding_weather.pkl', 'rb') as f:
    weather_map = pickle.load(f)

test_df['weather'] = test_df['weather'].map(weather_map)

# %% [markdown]
# #### エンコーディング

# %%
test_df['remarks'] = test_df['remarks'].notnull().astype(int)

# %%
test_df = pd.get_dummies(test_df, columns=['event'])

# %% [markdown]
# #### 標準化

# %%
# まず数値型のカラムを取得
num_cols = test_df.select_dtypes(include=['int', 'float']).drop(columns=["y"]).columns.tolist()

# その中から、binary (0か1しかない) 特徴量を除外
num_cols = [
    col for col in num_cols
    if test_df[col].nunique() > 2  # 0/1だけならnunique()は2になるので除外
]

# %%
outlier_value = -9999

for col in num_cols:
    # 外れ値を除いた部分で平均・標準偏差を計算
    mask = test_df[col] != outlier_value
    mean = test_df.loc[mask, col].mean()
    std = test_df.loc[mask, col].std()

    # 標準化（外れ値は後で0に置換）
    standardized = (test_df[col] - mean) / std

    # 結果を保存
    test_df[col] = standardized

# %% [markdown]
# #### 前処理済みのファイルをアウトプット

# %%
test_df.to_csv('./output/中間データ/test_preprocessed.csv', index=False)
